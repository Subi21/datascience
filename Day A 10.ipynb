# %% [markdown]
# # Day 10
# ___

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# !ls
# Out:
# 300
# API_EN.ATM.CO2E.KT_DS2_en_csv_v2
# API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv
# API_EN.ATM.CO2E.KT_DS2_en_csv_v2.zip
# Day 1.ipynb
# Day 2.ipynb
# Day 3.ipynb
# Day 4.ipynb
# Day 5.ipynb
# Day 6.ipynb
# Day 7.ipynb
# Day 8.ipynb
# Day A 10.ipynb
# LICENSE
# Matplotlib II.ipynb
# Metadata_Country_API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv
# Metadata_Indicator_API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv
# Numpy I.ipynb
# Numpy II.ipynb
# Numpy III and Matplotlib I.ipynb
# Pandas I.ipynb
# Pandas II.ipynb
# Pandas III.ipynb
# Pandas IV.ipynb
# Problems
# README.md
# References
# cat.jpg
# environment.yml
# practise.ipynb
# uni01-numpy-session.ipynb
# unit-01-data-session.ipynb
# unit-03-numpy.ipynb

# %%
# !dir
# Out:
# /bin/sh: dir: command not found

# %%
pd.read_csv('Metadata_Country_API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv')
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFG                  South Asia           Low income
# 2            AGO          Sub-Saharan Africa  Upper middle income
# 3            ALB       Europe & Central Asia  Upper middle income
# 4            AND       Europe & Central Asia          High income
# 5            ARB                         NaN                  NaN
# 6            ARE  Middle East & North Africa          High income
# 7            ARG   Latin America & Caribbean  Upper middle income
# 8            ARM       Europe & Central Asia  Lower middle income
# 9            ASM         East Asia & Pacific  Upper middle income
# 10           ATG   Latin America & Caribbean          High income
# 11           AUS         East Asia & Pacific          High income
# 12           AUT       Europe & Central Asia          High income
# ...

# %%
pd.read_csv('Metadata_Indicator_API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv')
# Out:
#    INDICATOR_CODE      INDICATOR_NAME  \
# 0  EN.ATM.CO2E.KT  CO2 emissions (kt)
#
#                                          SOURCE_NOTE  \
# 0  Carbon dioxide emissions are those stemming fr...
#
#                                  SOURCE_ORGANIZATION  Unnamed: 4
# 0  Carbon Dioxide Information Analysis Center, En...         NaN

# %%
# !head API_EN.ATM.CO2E.KT_DS2_en_csv_v2
# Out:
# head: Error reading API_EN.ATM.CO2E.KT_DS2_en_csv_v2

# %%
# !head API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv
# Out:
# ﻿"Data Source","World Development Indicators",
#
# "Last Updated Date","2017-03-23",
#
# "Country Name","Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016",
# "Aruba","ABW","CO2 emissions (kt)","EN.ATM.CO2E.KT","","","","","","","","","","","","","","","","","","","","","","","","","","","179.683","447.374","612.389","649.059","1730.824","1771.161","1558.475","1602.479","1595.145","1609.813","1617.147","1650.15","1712.489","1749.159","2321.211","2357.881","2372.549","2416.553","2420.22","2497.227","2497.227","2592.569","2508.228","2522.896","2456.89","2438.555","1301.785","876.413","","","",
# ...

# %%
df = pd.read_csv('API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv', skiprows= 3)

# %%
df
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                              Andorra          AND
# 2                                          Afghanistan          AFG
# 3                                               Angola          AGO
# 4                                              Albania          ALB
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
df[df["Country Name"]== 'Nepal']
# Out:
#     Country Name Country Code      Indicator Name  Indicator Code    1960  \
# 176        Nepal          NPL  CO2 emissions (kt)  EN.ATM.CO2E.KT  80.674
#
#        1961    1962    1963     1964     1965     ...           2008  \
# 176  80.674  88.008  99.009  150.347  179.683     ...       3421.311
#
#          2009      2010      2011      2012      2013  2014  2015  2016  \
# 176  4334.394  5056.793  5533.503  5845.198  6501.591   NaN   NaN   NaN
#
#      Unnamed: 61
# 176          NaN
#
# [1 rows x 62 columns]

# %%
ndf = df[df["Country Name"]== 'Nepal']

# %%
ndf.plot()
# Out:
# /Users/narendrapal/anaconda/lib/python3.6/site-packages/matplotlib/axes/_base.py:2903: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=176.0, right=176.0
#   'left=%s, right=%s') % (left, right))

# %%
ndf.T
# Out:
#                                176
# Country Name                 Nepal
# Country Code                   NPL
# Indicator Name  CO2 emissions (kt)
# Indicator Code      EN.ATM.CO2E.KT
# 1960                        80.674
# 1961                        80.674
# 1962                        88.008
# 1963                        99.009
# 1964                       150.347
# 1965                       179.683
# 1966                       190.684
# 1967                       212.686
# 1968                       253.023
# 1969                       399.703
# 1970                       227.354
# 1971                       198.018
# 1972                       267.691
# 1973                       421.705
# 1974                       425.372
# 1975                       352.032
# 1976                       282.359
# 1977                       337.364
# 1978                        330.03
# 1979                        513.38
# 1980                       542.716
# 1981                       454.708
# ...

# %%
ndf.drop(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'])
# Out:
# ----------------------------------------------------------------
# ValueError                     Traceback (most recent call last)
# <ipython-input-15-e28cb1f8881e> in <module>()
# ----> 1 ndf.drop(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'])
#
# /Users/narendrapal/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    1905                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1906             else:
# -> 1907                 new_axis = axis.drop(labels, errors=errors)
#    1908             dropped = self.reindex(**{axis_name: new_axis})
#    1909             try:
#
# /Users/narendrapal/anaconda/lib/python3.6/site-packages/pandas/indexes/base.py in drop(self, labels, errors)
#    3260             if errors != 'ignore':
#    3261                 raise ValueError('labels %s not contained in axis' %
# -> 3262                                  labels[mask])
# ...

# %%
ndf.drop(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], axis = 1)
# Out:
#        1960    1961    1962    1963     1964     1965     1966     1967  \
# 176  80.674  80.674  88.008  99.009  150.347  179.683  190.684  212.686
#
#         1968     1969     ...           2008      2009      2010      2011  \
# 176  253.023  399.703     ...       3421.311  4334.394  5056.793  5533.503
#
#          2012      2013  2014  2015  2016  Unnamed: 61
# 176  5845.198  6501.591   NaN   NaN   NaN          NaN
#
# [1 rows x 58 columns]

# %%
ndf
# Out:
#     Country Name Country Code      Indicator Name  Indicator Code    1960  \
# 176        Nepal          NPL  CO2 emissions (kt)  EN.ATM.CO2E.KT  80.674
#
#        1961    1962    1963     1964     1965     ...           2008  \
# 176  80.674  88.008  99.009  150.347  179.683     ...       3421.311
#
#          2009      2010      2011      2012      2013  2014  2015  2016  \
# 176  4334.394  5056.793  5533.503  5845.198  6501.591   NaN   NaN   NaN
#
#      Unnamed: 61
# 176          NaN
#
# [1 rows x 62 columns]

# %%
ndf.drop(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], axis = 1, inplace = True)
# Out:
# /Users/narendrapal/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
ndf
# Out:
#        1960    1961    1962    1963     1964     1965     1966     1967  \
# 176  80.674  80.674  88.008  99.009  150.347  179.683  190.684  212.686
#
#         1968     1969     ...           2008      2009      2010      2011  \
# 176  253.023  399.703     ...       3421.311  4334.394  5056.793  5533.503
#
#          2012      2013  2014  2015  2016  Unnamed: 61
# 176  5845.198  6501.591   NaN   NaN   NaN          NaN
#
# [1 rows x 58 columns]

# %%
ndf = ndf.T

# %%
ndf
# Out:
#                   176
# 1960           80.674
# 1961           80.674
# 1962           88.008
# 1963           99.009
# 1964          150.347
# 1965          179.683
# 1966          190.684
# 1967          212.686
# 1968          253.023
# 1969          399.703
# 1970          227.354
# 1971          198.018
# 1972          267.691
# 1973          421.705
# 1974          425.372
# 1975          352.032
# 1976          282.359
# 1977          337.364
# 1978          330.030
# 1979          513.380
# 1980          542.716
# 1981          454.708
# 1982          443.707
# 1983          495.045
# 1984          704.064
# 1985          678.395
# 1986          704.064
# 1987          872.746
# 1988          993.757
# 1989          913.083
# 1990          634.391
# 1991          960.754
# 1992         1331.121
# 1993         1466.800
# 1994         1697.821
# 1995         2035.185
# 1996         2486.226
# 1997         2783.253
# 1998         2251.538
# 1999         3219.626
# ...

# %%
ndf.columns =['Emission']

# %%
ndf
# Out:
#              Emission
# 1960           80.674
# 1961           80.674
# 1962           88.008
# 1963           99.009
# 1964          150.347
# 1965          179.683
# 1966          190.684
# 1967          212.686
# 1968          253.023
# 1969          399.703
# 1970          227.354
# 1971          198.018
# 1972          267.691
# 1973          421.705
# 1974          425.372
# 1975          352.032
# 1976          282.359
# 1977          337.364
# 1978          330.030
# 1979          513.380
# 1980          542.716
# 1981          454.708
# 1982          443.707
# 1983          495.045
# 1984          704.064
# 1985          678.395
# 1986          704.064
# 1987          872.746
# 1988          993.757
# 1989          913.083
# 1990          634.391
# 1991          960.754
# 1992         1331.121
# 1993         1466.800
# 1994         1697.821
# 1995         2035.185
# 1996         2486.226
# 1997         2783.253
# 1998         2251.538
# 1999         3219.626
# ...

# %%
ndf.dropna(inplace= True)

# %%
ndf
# Out:
#       Emission
# 1960    80.674
# 1961    80.674
# 1962    88.008
# 1963    99.009
# 1964   150.347
# 1965   179.683
# 1966   190.684
# 1967   212.686
# 1968   253.023
# 1969   399.703
# 1970   227.354
# 1971   198.018
# 1972   267.691
# 1973   421.705
# 1974   425.372
# 1975   352.032
# 1976   282.359
# 1977   337.364
# 1978   330.030
# 1979   513.380
# 1980   542.716
# 1981   454.708
# 1982   443.707
# 1983   495.045
# 1984   704.064
# 1985   678.395
# 1986   704.064
# 1987   872.746
# 1988   993.757
# 1989   913.083
# 1990   634.391
# 1991   960.754
# 1992  1331.121
# 1993  1466.800
# 1994  1697.821
# 1995  2035.185
# 1996  2486.226
# 1997  2783.253
# 1998  2251.538
# 1999  3219.626
# 2000  3069.279
# 2001  3267.297
# 2002  2625.572
# 2003  2841.925
# 2004  2669.576
# 2005  3083.947
# 2006  2563.233
# 2007  2614.571
# 2008  3421.311
# 2009  4334.394
# 2010  5056.793
# 2011  5533.503
# 2012  5845.198
# 2013  6501.591

# %%
ndf.plot()

# %%
ndf.index
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013'],
#       dtype='object')

# %%
de = pd.read_csv('Metadata_Country_API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv')

# %%
de
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFG                  South Asia           Low income
# 2            AGO          Sub-Saharan Africa  Upper middle income
# 3            ALB       Europe & Central Asia  Upper middle income
# 4            AND       Europe & Central Asia          High income
# 5            ARB                         NaN                  NaN
# 6            ARE  Middle East & North Africa          High income
# 7            ARG   Latin America & Caribbean  Upper middle income
# 8            ARM       Europe & Central Asia  Lower middle income
# 9            ASM         East Asia & Pacific  Upper middle income
# 10           ATG   Latin America & Caribbean          High income
# 11           AUS         East Asia & Pacific          High income
# 12           AUT       Europe & Central Asia          High income
# ...

# %%
de[de["Region"]== 'South Asia']
# Out:
#     Country Code      Region          IncomeGroup  \
# 1            AFG  South Asia           Low income
# 18           BGD  South Asia  Lower middle income
# 30           BTN  South Asia  Lower middle income
# 107          IND  South Asia  Lower middle income
# 136          LKA  South Asia  Lower middle income
# 150          MDV  South Asia  Upper middle income
# 176          NPL  South Asia           Low income
# 182          PAK  South Asia  Lower middle income
#
#                                           SpecialNotes    TableName  \
# 1    Fiscal year end: March 20; reporting period fo...  Afghanistan
# 18   Fiscal year end: June 30; reporting period for...   Bangladesh
# 30   April 2013 database update: Data were updated ...       Bhutan
# 107  Fiscal year end: March 31; reporting period fo...        India
# 136  Bureau of Census and Statistics revised nation...    Sri Lanka
# 150  April 2012 database update: The Department of ...     Maldives
# ...

# %%
nde = de[de["Region"]== 'South Asia']

# %%
nde
# Out:
#     Country Code      Region          IncomeGroup  \
# 1            AFG  South Asia           Low income
# 18           BGD  South Asia  Lower middle income
# 30           BTN  South Asia  Lower middle income
# 107          IND  South Asia  Lower middle income
# 136          LKA  South Asia  Lower middle income
# 150          MDV  South Asia  Upper middle income
# 176          NPL  South Asia           Low income
# 182          PAK  South Asia  Lower middle income
#
#                                           SpecialNotes    TableName  \
# 1    Fiscal year end: March 20; reporting period fo...  Afghanistan
# 18   Fiscal year end: June 30; reporting period for...   Bangladesh
# 30   April 2013 database update: Data were updated ...       Bhutan
# 107  Fiscal year end: March 31; reporting period fo...        India
# 136  Bureau of Census and Statistics revised nation...    Sri Lanka
# 150  April 2012 database update: The Department of ...     Maldives
# ...

# %%
nde.head()
# Out:
#     Country Code      Region          IncomeGroup  \
# 1            AFG  South Asia           Low income
# 18           BGD  South Asia  Lower middle income
# 30           BTN  South Asia  Lower middle income
# 107          IND  South Asia  Lower middle income
# 136          LKA  South Asia  Lower middle income
#
#                                           SpecialNotes    TableName  \
# 1    Fiscal year end: March 20; reporting period fo...  Afghanistan
# 18   Fiscal year end: June 30; reporting period for...   Bangladesh
# 30   April 2013 database update: Data were updated ...       Bhutan
# 107  Fiscal year end: March 31; reporting period fo...        India
# 136  Bureau of Census and Statistics revised nation...    Sri Lanka
#
#      Unnamed: 5
# 1           NaN
# 18          NaN
# 30          NaN
# 107         NaN
# 136         NaN

# %%
df['Country Code'].isin(['ALB'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 234    False
# 235    False
# 236    False
# 237    False
# 238    False
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# 247    False
# 248    False
# 249    False
# 250    False
# 251    False
# 252    False
# 253    False
# 254    False
# 255    False
# 256    False
# 257    False
# 258    False
# 259    False
# 260    False
# 261    False
# 262    False
# 263    False
# Name: Country Code, dtype: bool

# %%
df[df['Country Code'].isin(['ALB'])]
# Out:
#   Country Name Country Code      Indicator Name  Indicator Code      1960  \
# 4      Albania          ALB  CO2 emissions (kt)  EN.ATM.CO2E.KT  2024.184
#
#        1961      1962      1963     1964      1965     ...           2008  \
# 4  2280.874  2464.224  2082.856  2016.85  2174.531     ...       4374.731
#
#        2009      2010      2011      2012      2013  2014  2015  2016  \
# 4  4378.398  4598.418  5240.143  4712.095  4814.771   NaN   NaN   NaN
#
#    Unnamed: 61
# 4          NaN
#
# [1 rows x 62 columns]

# %%
sdf = df[df['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'])]]
# Out:
#   File "<ipython-input-36-d806c6a20f18>", line 1
#     sdf = df[df['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'])]]
#                                                                                    ^
# SyntaxError: invalid syntax

# %%
sdf.head()
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# <ipython-input-37-896b1c3fcadc> in <module>()
# ----> 1 sdf.head()
#
# NameError: name 'sdf' is not defined

# %%
sdf.set_index('Country Name')
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# <ipython-input-38-e68c45083400> in <module>()
# ----> 1 sdf.set_index('Country Name')
#
# NameError: name 'sdf' is not defined

# %%
sdf = sdf.T
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# <ipython-input-39-decf8fdf3b6a> in <module>()
# ----> 1 sdf = sdf.T
#
# NameError: name 'sdf' is not defined

# %%
sdf
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# <ipython-input-40-d9cca721a735> in <module>()
# ----> 1 sdf
#
# NameError: name 'sdf' is not defined

# %%
sdf[['Bangladesh','Nepal'
# Out:
#   File "<ipython-input-41-c4193f52eef3>", line 1
#     sdf[['Bangladesh','Nepal'
#                              ^
# SyntaxError: unexpected EOF while parsing

# %%
ndf.plot()

# %%
de
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFG                  South Asia           Low income
# 2            AGO          Sub-Saharan Africa  Upper middle income
# 3            ALB       Europe & Central Asia  Upper middle income
# 4            AND       Europe & Central Asia          High income
# 5            ARB                         NaN                  NaN
# 6            ARE  Middle East & North Africa          High income
# 7            ARG   Latin America & Caribbean  Upper middle income
# 8            ARM       Europe & Central Asia  Lower middle income
# 9            ASM         East Asia & Pacific  Upper middle income
# 10           ATG   Latin America & Caribbean          High income
# 11           AUS         East Asia & Pacific          High income
# 12           AUT       Europe & Central Asia          High income
# ...

# %%
nde
# Out:
#     Country Code      Region          IncomeGroup  \
# 1            AFG  South Asia           Low income
# 18           BGD  South Asia  Lower middle income
# 30           BTN  South Asia  Lower middle income
# 107          IND  South Asia  Lower middle income
# 136          LKA  South Asia  Lower middle income
# 150          MDV  South Asia  Upper middle income
# 176          NPL  South Asia           Low income
# 182          PAK  South Asia  Lower middle income
#
#                                           SpecialNotes    TableName  \
# 1    Fiscal year end: March 20; reporting period fo...  Afghanistan
# 18   Fiscal year end: June 30; reporting period for...   Bangladesh
# 30   April 2013 database update: Data were updated ...       Bhutan
# 107  Fiscal year end: March 31; reporting period fo...        India
# 136  Bureau of Census and Statistics revised nation...    Sri Lanka
# 150  April 2012 database update: The Department of ...     Maldives
# ...

# %%
ab = (nde['Country Code'])

# %%
ab
# Out:
# 1      AFG
# 18     BGD
# 30     BTN
# 107    IND
# 136    LKA
# 150    MDV
# 176    NPL
# 182    PAK
# Name: Country Code, dtype: object

# %%
sal = df[df['Country Code'].isin(ab.values)]

# %%
sal
# Out:
#     Country Name Country Code      Indicator Name  Indicator Code        1960  \
# 2    Afghanistan          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT     414.371
# 18    Bangladesh          BGD  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# 30        Bhutan          BTN  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# 106        India          IND  CO2 emissions (kt)  EN.ATM.CO2E.KT  120581.961
# 136    Sri Lanka          LKA  CO2 emissions (kt)  EN.ATM.CO2E.KT    2258.872
# 150     Maldives          MDV  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# 176        Nepal          NPL  CO2 emissions (kt)  EN.ATM.CO2E.KT      80.674
# 182     Pakistan          PAK  CO2 emissions (kt)  EN.ATM.CO2E.KT   14154.620
#
#            1961        1962        1963        1964        1965     ...       \
# 2       491.378     689.396     707.731     839.743    1008.425     ...
# 18          NaN         NaN         NaN         NaN         NaN     ...
# ...

# %%
sal.set_index(['Country Name'],inplace = True)

# %%
sal
# Out:
#              Country Code      Indicator Name  Indicator Code        1960  \
# Country Name
# Afghanistan           AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT     414.371
# Bangladesh            BGD  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# Bhutan                BTN  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# India                 IND  CO2 emissions (kt)  EN.ATM.CO2E.KT  120581.961
# Sri Lanka             LKA  CO2 emissions (kt)  EN.ATM.CO2E.KT    2258.872
# Maldives              MDV  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# Nepal                 NPL  CO2 emissions (kt)  EN.ATM.CO2E.KT      80.674
# Pakistan              PAK  CO2 emissions (kt)  EN.ATM.CO2E.KT   14154.620
#
#                     1961        1962        1963        1964        1965  \
# Country Name
# Afghanistan      491.378     689.396     707.731     839.743    1008.425
# Bangladesh           NaN         NaN         NaN         NaN         NaN
# ...

# %%
sal.drop([ 'Country Code', 'Indicator Name', 'Indicator Code'], inplace = True, axis = 1)
# Out:
# /Users/narendrapal/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
sal
# Out:
#                     1960        1961        1962        1963        1964  \
# Country Name
# Afghanistan      414.371     491.378     689.396     707.731     839.743
# Bangladesh           NaN         NaN         NaN         NaN         NaN
# Bhutan               NaN         NaN         NaN         NaN         NaN
# India         120581.961  130402.187  143467.708  154083.673  150647.694
# Sri Lanka       2258.872    2335.879    2563.233    2533.897    2273.540
# Maldives             NaN         NaN         NaN         NaN         NaN
# Nepal             80.674      80.674      88.008      99.009     150.347
# Pakistan       14154.620   14656.999   16105.464   18514.683   19035.397
#
#                     1965        1966        1967        1968        1969  \
# Country Name
# Afghanistan     1008.425    1092.766    1283.450    1224.778     942.419
# Bangladesh           NaN         NaN         NaN         NaN         NaN
# ...

# %%
sal = sal.T

# %%
sal
# Out:
# Country Name  Afghanistan  Bangladesh   Bhutan        India  Sri Lanka  \
# 1960              414.371         NaN      NaN   120581.961   2258.872
# 1961              491.378         NaN      NaN   130402.187   2335.879
# 1962              689.396         NaN      NaN   143467.708   2563.233
# 1963              707.731         NaN      NaN   154083.673   2533.897
# 1964              839.743         NaN      NaN   150647.694   2273.540
# 1965             1008.425         NaN      NaN   165972.087   2658.575
# 1966             1092.766         NaN      NaN   171765.947   2662.242
# 1967             1283.450         NaN      NaN   172238.990   2948.268
# 1968             1224.778         NaN      NaN   187336.029   3241.628
# 1969              942.419         NaN      NaN   190724.337   4319.726
# 1970             1672.152         NaN    3.667   195143.072   3597.327
# 1971             1895.839         NaN    3.667   205869.047   3197.624
# ...

# %%
sal.plot()

# %%
import seaborn as sns 
sns.set()

# %%
sal.plot()

# %%
sdf = sal[['Bhutan','Maldives','Sri Lanka','Nepal','Afghanistan','Bangladesh']]

# %%
sdf
# Out:
# Country Name   Bhutan  Maldives  Sri Lanka     Nepal  Afghanistan  Bangladesh
# 1960              NaN       NaN   2258.872    80.674      414.371         NaN
# 1961              NaN       NaN   2335.879    80.674      491.378         NaN
# 1962              NaN       NaN   2563.233    88.008      689.396         NaN
# 1963              NaN       NaN   2533.897    99.009      707.731         NaN
# 1964              NaN       NaN   2273.540   150.347      839.743         NaN
# 1965              NaN       NaN   2658.575   179.683     1008.425         NaN
# 1966              NaN       NaN   2662.242   190.684     1092.766         NaN
# 1967              NaN       NaN   2948.268   212.686     1283.450         NaN
# 1968              NaN       NaN   3241.628   253.023     1224.778         NaN
# 1969              NaN       NaN   4319.726   399.703      942.419         NaN
# 1970            3.667       NaN   3597.327   227.354     1672.152         NaN
# ...

# %%
sdf.plot()

# %%
pd.merge(df,nde).head()
# Out:
#   Country Name Country Code      Indicator Name  Indicator Code        1960  \
# 0  Afghanistan          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT     414.371
# 1   Bangladesh          BGD  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# 2       Bhutan          BTN  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# 3        India          IND  CO2 emissions (kt)  EN.ATM.CO2E.KT  120581.961
# 4    Sri Lanka          LKA  CO2 emissions (kt)  EN.ATM.CO2E.KT    2258.872
#
#          1961        1962        1963        1964        1965     ...      \
# 0     491.378     689.396     707.731     839.743    1008.425     ...
# 1         NaN         NaN         NaN         NaN         NaN     ...
# 2         NaN         NaN         NaN         NaN         NaN     ...
# 3  130402.187  143467.708  154083.673  150647.694  165972.087     ...
# 4    2335.879    2563.233    2533.897    2273.540    2658.575     ...
#
#           2013  2014  2015  2016  Unnamed: 61      Region  \
# ...

# %%
pd.merge(df,de).head()
# Out:
#   Country Name Country Code      Indicator Name  Indicator Code      1960  \
# 0        Aruba          ABW  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
# 1      Andorra          AND  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
# 2  Afghanistan          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT   414.371
# 3       Angola          AGO  CO2 emissions (kt)  EN.ATM.CO2E.KT   550.050
# 4      Albania          ALB  CO2 emissions (kt)  EN.ATM.CO2E.KT  2024.184
#
#        1961      1962      1963      1964      1965     ...           2013  \
# 0       NaN       NaN       NaN       NaN       NaN     ...        876.413
# 1       NaN       NaN       NaN       NaN       NaN     ...        491.378
# 2   491.378   689.396   707.731   839.743  1008.425     ...      21268.600
# 3   454.708  1180.774  1151.438  1224.778  1188.108     ...      32463.951
# 4  2280.874  2464.224  2082.856  2016.850  2174.531     ...       4814.771
#
#    2014  2015  2016  Unnamed: 61                     Region  \
# ...

# %%
sdf.columns
# Out:
# Index(['Bhutan', 'Maldives', 'Sri Lanka', 'Nepal', 'Afghanistan',
#        'Bangladesh'],
#       dtype='object', name='Country Name')

# %%
sdf.columns.difference(['India'])
# Out:
# Index(['Afghanistan', 'Bangladesh', 'Bhutan', 'Maldives', 'Nepal',
#        'Sri Lanka'],
#       dtype='object', name='Country Name')

# %%
sdf[sdf.columns.difference(['India','Pakistan'])]
# Out:
# Country Name  Afghanistan  Bangladesh   Bhutan  Maldives     Nepal  Sri Lanka
# 1960              414.371         NaN      NaN       NaN    80.674   2258.872
# 1961              491.378         NaN      NaN       NaN    80.674   2335.879
# 1962              689.396         NaN      NaN       NaN    88.008   2563.233
# 1963              707.731         NaN      NaN       NaN    99.009   2533.897
# 1964              839.743         NaN      NaN       NaN   150.347   2273.540
# 1965             1008.425         NaN      NaN       NaN   179.683   2658.575
# 1966             1092.766         NaN      NaN       NaN   190.684   2662.242
# 1967             1283.450         NaN      NaN       NaN   212.686   2948.268
# 1968             1224.778         NaN      NaN       NaN   253.023   3241.628
# 1969              942.419         NaN      NaN       NaN   399.703   4319.726
# 1970             1672.152         NaN    3.667       NaN   227.354   3597.327
# ...

# %%
sdf.loc['2000':'2013']
# Out:
# Country Name   Bhutan  Maldives  Sri Lanka     Nepal  Afghanistan  Bangladesh
# 2000          396.036   451.041  10238.264  3069.279      773.737   27869.200
# 2001          385.035   462.042  10443.616  3267.297      638.058   32456.617
# 2002          418.038   594.054  11056.005  2625.572      883.747   33707.064
# 2003          377.701   506.046  11078.007  2841.925     1026.760   35672.576
# 2004          308.028   667.394  12299.118  2669.576      949.753   37704.094
# 2005          396.036   601.388  12101.100  3083.947     1327.454   39478.922
# 2006          392.369   759.069  11976.422  2563.233     1650.150   43541.958
# 2007          392.369   781.071  12354.123  2614.571     2273.540   44407.370
# 2008          421.705   843.410  12207.443  3421.311     4217.050   49559.505
# 2009          388.702   883.747  13175.531  4334.394     6776.616   53824.226
# 2010          487.711   898.415  13688.911  5056.793     8470.770   59992.120
# ...

# %%
sdf.loc['2000':'2013'].sum()
# Out:
# Country Name
# Bhutan           6798.618
# Maldives        10527.957
# Sri Lanka      178102.523
# Nepal           53428.190
# Afghanistan     82962.208
# Bangladesh     658215.499
# dtype: float64

# %%
sdf.loc['2000':'2013'].sum(axis = 1)
# Out:
# 2000     42797.557
# 2001     47652.665
# 2002     49284.480
# 2003     51503.015
# 2004     54597.963
# 2005     56988.847
# 2006     60883.201
# 2007     62823.044
# 2008     70670.424
# 2009     79383.216
# 2010     88594.720
# 2011     98275.600
# 2012    111902.172
# 2013    114678.091
# dtype: float64

# %%
sdf.loc['2000':'2013'].sum().plot(kind = 'bar')

# %% [markdown]
# ** plot forest land against agricultural land**
# **use 5 of forest area and 5 agricultural area and plot graph against**
